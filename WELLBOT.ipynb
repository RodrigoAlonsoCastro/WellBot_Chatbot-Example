# %% [markdown]
# Different scenarios aa coded. Having trouble when putting it all together, the combined code we have so far is added at the very end.

# %% [markdown]
# Ordering prescription tab(Mahrukh):

# %%
import random
import pandas as pd

# Simulated prescription database
prescriptions = {}

def generate_prescription_number():
    return f"RX{random.randint(1000, 9999)}"

def new_prescription(medication, dosage, instructions, refills, fax_needed, telephone_number=None):
    prescription_number = generate_prescription_number()
    prescription = {
        'prescription_number': prescription_number,
        'medication': medication,
        'dosage': dosage,
        'instructions': instructions,
        'refills': refills,
        'sending_pharmacy': 'N/A',
        'fax_needed': fax_needed,
        'telephone_number': telephone_number,
    }
    prescriptions[prescription_number] = prescription

def generate_random_prescription_data():
    medication = f"Medication_{random.randint(1, 100)}"
    dosage = f"{random.randint(1, 20)}mg"
    instructions = f"Take {random.randint(1, 3)} times daily"
    refills = random.randint(0, 5)
    return medication, dosage, instructions, refills

data = {
    'Medication': ['Aspirin', 'Ibuprofen'],
    'Brand_Public': [10.0, 12.0],
    'Brand_Private': [8.0, 10.0],
    'Brand_Manufacturer_Rebate': [1.0, 1.5],
    'Generic_Public': [5.0, 6.0],
    'Generic_Private': [4.0, 5.0],
    'Generic_Manufacturer_Rebate': [0.5, 0.7]
}

def get_drug_price(medication, category, medication_type):
    col_name = f'{medication_type}_{category}'
    try:
        price = df.loc[df['Medication'].str.lower() == medication.lower(), col_name].values[0]
        return price
    except IndexError:
        return None

if __name__ == '__main__':
    df = pd.DataFrame(data)  # Provided drug pricing data

    print("Welcome to the ordering prescriptions tab!")

    while True:
        print("1. Initiate Prescription Transfer (Incoming)")
        print("2. Submit New Prescription")
        print("3. Get Drug Price")
        choice = input("Select an option (1/2/3): ")

        if choice == '1':
            print("\nInitiate Prescription Transfer (Incoming)")
            sending_pharmacy = input("Enter the name of the sending pharmacy: ")

            # Generate a random prescription number for the incoming transfer
            prescription_number = generate_prescription_number()

            print(f"Generated Prescription Number: {prescription_number}")

            fax_needed = True  # Fax is always needed for prescription transfer
            telephone_number = input("Enter the telephone number of the sending pharmacy: ")

            # Generate random prescription data for transfer
            medication, dosage, instructions, refills = generate_random_prescription_data()
            new_prescription(medication, dosage, instructions, refills, fax_needed, telephone_number)
            print(f"Prescription {prescription_number} initiated for transfer from {sending_pharmacy}. Telephone number: {telephone_number}")

        elif choice == '2':
            medication = input("Enter the medication name: ")
            dosage = input("Enter the dosage: ")
            instructions = input("Enter the instructions: ")
            refills = input("Enter the number of refills: ")

            fax_needed = input("Fax of prescription from doctor's office needed? (y/n): ").lower() == 'y'
            telephone_number = None
            if fax_needed:
                telephone_number = input("Enter the telephone number of the doctor's office: ")

            new_prescription(medication, dosage, instructions, refills, fax_needed, telephone_number)
            print("Prescription submitted successfully.")

        elif choice == '3':
            medication = input("Enter the medication name: ").lower()
            category = input("Select category (Public/Private Insurance): ").title()
            medication_type = input("Select medication type (Brand/Generic): ").title()

            manufacturer_rebate = input("Do you have a manufacturer rebate? (y/n): ")
            if manufacturer_rebate.lower() == 'y':
                has_rebate = True
            else:
                has_rebate = False

            price = get_drug_price(medication, category, medication_type)

            if has_rebate and price is not None:
                manufacturer_rebate = df.loc[df['Medication'].str.lower() == medication, f'{medication_type}_Manufacturer_Rebate'].values[0]
                price -= manufacturer_rebate

            if price is not None:
                print(f"The price of {medication_type} {medication} under {category} Insurance is ${price:.2f}")
            else:
                print("Invalid input or medication not found.")

        else:
            print("Invalid choice. Please select 1, 2, or 3.")

        another_action = input("Do you want to perform another action? (y/n): ")
        if another_action.lower() != "y":
            print("\nPrescription Database:")
            for prescription_number, prescription in prescriptions.items():
                print(f"Prescription Number: {prescription_number}")
                print(f"Medication: {prescription['medication']}")
                print(f"Dosage: {prescription['dosage']}")
                print(f"Instructions: {prescription['instructions']}")
                print(f"Refills: {prescription['refills']}")
                if 'sending_pharmacy' in prescription:
                    print(f"Sending Pharmacy: {prescription['sending_pharmacy']}")
                if 'fax_needed' in prescription:
                    print(f"Fax Needed: {'Yes' if prescription['fax_needed'] else 'No'}")
                if prescription.get('fax_needed') and 'telephone_number' in prescription:
                    print(f"Telephone Number: {prescription['telephone_number']}")
                print("-" * 20)
            break

# %% [markdown]
# Prescription Management (Rodrigo):

# %%
# Create a function to ask for refills of medicines (use prescription_refill dict.)
def refill_prescription():
    orders = []
    while True:
        prescription_number = input("Please enter your prescription number: ")
        while prescription_number not in [str(key) for key in prescription_refill.keys()]:
            prescription_number = input("Invalid prescription number. Please try again or enter 'x' to exit WellBot: ")
            if prescription_number.lower() == 'x':
                print("Thank you for using WellBot!")
                return
            continue
        name = input("Please enter your full name: ")
        email = input("Please enter your email address: ")
        address = input("Please enter your delivery address: ")
        medicine = prescription_refill[int(prescription_number)]
        order = {
            "prescription_number": prescription_number,
            "customer": name,
            "email": email,
            "address": address,
            "medicine": medicine
        }
        orders.append(order)
        print(f"\nOrder Summary:\nPrescription Number: {prescription_number}\nCustomer: {name}\nEmail: {email}\nDelivery Address: {address}\nMedicine: {medicine}")
        print("\nOrder placed! We will send you an email with the delivery information.")
        choice = input("\nWould you like to place another order? (y/n): ")
        if choice.lower() != 'y':
            break

# Create a function to check if certain medicine is in stock (use stock dict.)
def check_availability():
    while True:
        medicine_name = input("Please enter the name of the medicine you want to check: ").capitalize()
        while medicine_name not in list(stock.keys()):
            medicine_name = input(f"Sorry, we don't have {medicine_name} in our inventory. Please try again or enter 'x' to exit WellBot: ").capitalize()
            if medicine_name.lower() == 'x':
                print("Thank you for using WellBot!")
                return
            continue
        available_stock = stock[medicine_name]
        if available_stock > 0:
            print(f"{medicine_name} is available, we have {available_stock} units in stock.")
        else:
            print(f"Sorry, {medicine_name} is currently out of stock.")
        choice = input("\nWould you like to check another medicine? (y/n): ")
        if choice.lower() != 'y':
            break

# Create a function to inform about the order status of presciption number (use delivery_status dict.)
def order_status():
    while True:
        prescription_number = input("Please enter your prescription number: ")
        while prescription_number not in [str(key) for key in delivery_status.keys()]:
            prescription_number = input("Invalid prescription number. Please try again or enter 'x' to exit WellBot: ")
            if prescription_number.lower() == 'x':
                print("Thank you for using WellBot!")
                return
            continue
        status = delivery_status[int(prescription_number)]
        print(f"\nThe order status for prescription number {prescription_number} is: {status}")
        if status in ['Canceled', 'On Hold', 'Rescheduled']:
            print('For further assistance, please contact our call center: 514 123 4567')
        choice = input("\nWould you like to check another order? (y/n): ")
        if choice.lower() != 'y':
            break

# The prescription_refill dict. match a prescription number to a medicine
prescription_refill = {
        1111:'Amoxicillin',
        2222:'Ibuprofen',
        3333:'Lisinopril',
        4444:'Metformin',
        5555:'Levothyroxine',
        6666:'Atorvastatin',
        7777:'Amlodipine',
        8888:'Omeprazole',
        9999:'Losartan'}

# The stock dict. match a medicine with it's current stock
stock = {
        'Amoxicillin': 100,
        'Ibuprofen': 200,
        'Lisinopril': 150,
        'Metformin': 120,
        'Levothyroxine': 80,
        'Atorvastatin': 90,
        'Amlodipine': 110,
        'Omeprazole': 130,
        'Losartan': 140}

# The delivery status macth a prescription number with the status of the delivery
delivery_status = {
        1111:'Canceled',
        2222:'In Transit',
        3333:'Rescheduled',
        4444:'Delivered',
        5555:'On Hold',
        6666:'In Transit',
        7777:'Canceled',
        8888:'Delivered',
        9999:'In Transit'}

# Create a function to call all the options under the PRESCRIPTION MANAGEMENT scenario
def prescription_management():
    if __name__ == "__main__":
        while True:
            print("\nPlease select an option: ")
            print("1. Refill Medication")
            print("2. Check Medication Availability")
            print("3. Check Order Status")
            print("4. Exit")

            option = input("Select the number: ")

            if option == '1':
                refill_prescription()
            elif option == '2':
                check_availability()
            elif option == '3':
                order_status()
            elif option == '4':
                break
            else:
                print("\nInvalid option. Please choose a valid option.")

if __name__ == "__main__":
    prescription_management()
# Out:
# Please select an option:
# 1. Refill Medication
# 2. Check Medication Availability
# 3. Check Order Status
# 4. Exit
# Select the number: 1
# Please enter your prescription number: 6574
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ab6c3205a5c9> in <cell line: 127>()
#     126
#     127 if __name__ == "__main__":
# --> 128     prescription_management()
#
# <ipython-input-1-ab6c3205a5c9> in prescription_management()
#     115
#     116             if option == '1':
# --> 117                 refill_prescription()
#     118             elif option == '2':
#     119                 check_availability()
#
# <ipython-input-1-ab6c3205a5c9> in refill_prescription()
#       4     while True:
#       5         prescription_number = input("Please enter your prescription number: ")
# ----> 6         while prescription_number not in [str(key) for key in prescription_refill.keys()]:
#       7             prescription_number = input("Invalid prescription number. Please try again or enter 'x' to exit WellBot: ")
#       8             if prescription_number.lower() == 'x':
#
# NameError: name 'prescription_refill' is not defined

# %% [markdown]
# Medication Information - Aasna

# %%
import requests

# customer dictionary
customers = {}

def fetch_medication_info(medication_name):
    api_url = f"https://api.fda.gov/drug/label.json?search=openfda.brand_name:{medication_name}&limit=1"
    response = requests.get(api_url)

    if response.status_code == 200:
        data = response.json()
        if "results" in data and data["results"]:
            medication_info = data["results"][0]
            return medication_info
    return None

def medication_information():
    medication_name = input("Enter the medication name: ")
    medication_info = fetch_medication_info(medication_name)
    if medication_info:
        print(f"Medication Name: {medication_info['openfda']['brand_name'][0]}")
        print(f"Manufacturer: {medication_info['openfda']['manufacturer_name'][0]}")

        while True:
            while True:
                # Prompt the user for specific information
                print("\nSelect the type of information you'd like to know:")
                print("1. Dosage Information")
                print("2. Allergy Information")
                print("3. General Information/Interactions")
                print("4. Go back to Medication Selection")
                print("5. Return to Welcome Section")
                print("6. Provide Feedback/Improvement")
                print("7. Exit")

                info_choice = input("Enter your choice: ")

                if info_choice == "1":
                    if "dosage_and_administration" in medication_info:
                        print("Dosage and Administration:")
                        for dosage in medication_info["dosage_and_administration"]:
                            print(f"  - {dosage}")
                    else:
                        print("Dosage information not available.")

                    more_info = input("Would you like more info? (yes/no): ")
                    if more_info.lower() == "yes":
                        break
                    else:
                        return True

                elif info_choice == "2":
                    if "warnings" in medication_info:
                        print("Allergy Information:")
                        for warning in medication_info["warnings"]:
                            print(f"  - {warning}")
                    else:
                        print("Allergy information not available.")

                    more_info = input("Would you like more info? (yes/no): ")
                    if more_info.lower() == "yes":
                        break
                    else:
                        return True

                elif info_choice == "3":
                    # Display general information or interactions
                    # Note: You need to determine what specific information you want to display here.
                    print("General Information/Interactions:")
                    print("This section is currently not implemented.")

                    more_info = input("Would you like more info? (yes/no): ")
                    if more_info.lower() == "yes":
                        break
                    else:
                        return True

                elif info_choice == "4":
                    return False  # Exit the medication information loop and return to main menu

                elif info_choice == "5":
                    print("Returning to Welcome Section.")
                    return False

                elif info_choice == "6":
                    feedback = input("Enter your feedback/improvement suggestion: ")
                    # You can implement a feedback submission mechanism here
                    print("Thank you for your feedback!")

                elif info_choice == "7":
                    print("Thank you for using the pharmacy chatbot. Goodbye!")
                    exit()

                else:
                    print("Invalid choice.")

        return True

    else:
        print("Medication not found.")
        return False

# Main loop
while True:
    print("\nHello and welcome, how can I help you today?")
    customer_name = input("What's your name? ")

    if customer_name in customers:
        customer = customers[customer_name]
        print(f"Welcome, {customer['name']}!")
    else:
        customers[customer_name] = {"name": customer_name, "prescriptions": [], "orders": []}
        print("Welcome! It looks like you're a new customer. Let's get started.")

    while True:
        print("\nWelcome menu options:")
        print("1. Prescription Management")
        print("2. Medication Order")
        print("3. Medication Information Index")
        print("4. Feedback/Improvement")
        print("5. Exit")

        choice = input("Enter your choice: ")

        if choice == "1":
            print("Prescription management feature not implemented in this example.")
        elif choice == "2":
            print("Medication order feature not implemented in this example.")
        elif choice == "3":
            if medication_information():
                print("\n1. Go back to Welcome Menu")
                print("2. Provide Feedback/Improvement")
                print("3. Exit")

                feedback_choice = input("Enter your choice: ")

                if feedback_choice == "1":
                    break
                elif feedback_choice == "2":
                    feedback = input("Enter your feedback/improvement suggestion: ")
                    # You can implement a feedback submission mechanism here
                    print("Thank you for your feedback!")
                elif feedback_choice == "3":
                    print("Thank you for using the pharmacy chatbot. Goodbye!")
                    exit()
                else:
                    print("Invalid choice. Exiting.")
                    exit()
        elif choice == "4":
            feedback = input("Enter your feedback/improvement suggestion: ")
            # You can implement a feedback submission mechanism here
            print("Thank you for your feedback!")
        elif choice == "5":
            print("Thank you for using the pharmacy chatbot. Goodbye!")
            exit()
        else:
            print("Invalid choice. Please choose a valid option.")

# %% [markdown]
# Feedback - Aasna

# %%
import requests
import json

# customer dictionary
customers = {}



def feedback_improvement():
    print("Thank you for providing feedback!")

    while True:
        print("\nFeedback/Improvement Options:")
        print("1. Need further assistance (email/call pharmacy support)")
        print("2. Rate our service (1-10)")
        print("3. How can we improve our service")
        print("4. Go back to Welcome Menu")
        print("5. Exit")

        feedback_choice = input("Enter your choice: ")

        if feedback_choice == "1":
            # Implement the email/call functionality here
            print("You selected: Need further assistance.")
            print("For further assistance call us toll-free at 1-866-640-3800")
            break
        elif feedback_choice == "2":
            rating = input("How would you rate our service (1-10)? ")
            store_rating(rating)
            # You can process the rating and take actions accordingly
            print(f"You rated our service: {rating}")
            break

        elif feedback_choice == "3":
            improvement = input("How can we improve our service? ")
            # Store the improvement suggestion in a JSON file
            store_improvement(improvement)
            print("Thank you for your input!")
            break

        elif feedback_choice == "4":
            return False  # Return to the welcome menu

        elif feedback_choice == "5":
            print("Thank you for using the pharmacy chatbot. Goodbye!")
            exit()

        else:
            print("Invalid choice.")

    return True

def store_improvement(suggestion):
    # Load existing improvements from JSON file
    try:
        with open("improvements.json", "r") as f:
            improvements = json.load(f)
    except (FileNotFoundError, json.JSONDecodeError):
        improvements = []

    # Add the new suggestion
    improvements.append(suggestion)

    # Write the updated improvements to the JSON file
    with open("improvements.json", "w") as f:
        json.dump(improvements, f, indent=4)
def store_rating(rating):
    # Load existing ratings from JSON file
    try:
        with open("ratings.json", "r") as f:
            ratings = json.load(f)
    except (FileNotFoundError, json.JSONDecodeError):
        ratings = []

    # Add the new rating
    ratings.append(rating)

    # Write the updated ratings to the JSON file
    with open("ratings.json", "w") as f:
        json.dump(ratings, f, indent=4)
# Main loop
while True:
  print("\nHello and welcome, how can I help you today?")
  customer_name = input("What's your name? ")

  if customer_name in customers:
        customer = customers[customer_name]
        print(f"Welcome, {customer['name']}!")
  else:
        customers[customer_name] = {"name": customer_name, "prescriptions": [], "orders": []}
        print("Welcome! It looks like you're a new customer. Let's get started.")

  while True:
        print("\nWelcome menu options:")
        print("1. Prescription Management")
        print("2. Medication Order")
        print("3. Medication Information Index")
        print("4. Feedback/Improvement")
        print("5. Exit")

        choice = input("Enter your choice: ")

        if choice == "1":
            print("Prescription management feature not implemented in this example.")
        elif choice == "2":
            print("Medication order feature not implemented in this example.")
        elif choice == "3":
            if medication_information():
                print("\n1. Go back to Welcome Menu")
                print("2. Provide Feedback/Improvement")
                print("3. Exit")

                feedback_choice = input("Enter your choice: ")

                if feedback_choice == "1":
                    break
                elif feedback_choice == "2":
                    feedback = input("Enter your feedback/improvement suggestion: ")
                    # You can implement a feedback submission mechanism here
                    print("Thank you for your feedback!")
                elif feedback_choice == "3":
                    print("Thank you for using the pharmacy chatbot. Goodbye!")
                    exit()
                else:
                    print("Invalid choice. Exiting.")
                    exit()
        elif choice == "4":
            if feedback_improvement():
                print("\n1. Go back to Welcome Menu")
                print("2. Exit")

                feedback_choice = input("Enter your choice: ")

                if feedback_choice == "1":
                    break
                elif feedback_choice == "2":
                    print("Thank you for using the pharmacy chatbot. Goodbye!")
                    exit()
                else:
                    print("Invalid choice. Exiting.")
                    exit()
        elif choice == "5":
            print("Thank you for using the pharmacy chatbot. Goodbye!")
            exit()
        else:
            print("Invalid choice. Please choose a valid option.")

# %% [markdown]
# Combined code: Having trouble here!

# %%
import requests
import json
import random
import pandas as pd

# Prescription Ordering
# Simulated prescription database
prescriptions = {}
stock = {}
delivery_status = {}

def p_ordering():
    def generate_prescription_number():
        return f"RX{random.randint(1000, 9999)}"

    def new_prescription(medication, dosage, instructions, refills, fax_needed, telephone_number=None):
        prescription_number = generate_prescription_number()
        prescription = {
            'prescription_number': prescription_number,
            'medication': medication,
            'dosage': dosage,
            'instructions': instructions,
            'refills': refills,
            'sending_pharmacy': 'N/A',
            'fax_needed': fax_needed,
            'telephone_number': telephone_number,
        }
        prescriptions[prescription_number] = prescription

    def generate_random_prescription_data():
        medication = f"Medication_{random.randint(1, 100)}"
        dosage = f"{random.randint(1, 20)}mg"
        instructions = f"Take {random.randint(1, 3)} times daily"
        refills = random.randint(0, 5)
        return medication, dosage, instructions, refills

    def get_drug_price(medication, category, medication_type):
        col_name = f'{medication_type}_{category}'
        data = {
            'Medication': ['Aspirin', 'Ibuprofen'],
            'Brand_Public': [10.0, 12.0],
            'Brand_Private': [8.0, 10.0],
            'Brand_Manufacturer_Rebate': [1.0, 1.5],
            'Generic_Public': [5.0, 6.0],
            'Generic_Private': [4.0, 5.0],
            'Generic_Manufacturer_Rebate': [0.5, 0.7]
            }
        df = pd.DataFrame(data)  # Provided drug pricing data

        try:
            price = df.loc[df['Medication'].str.lower() == medication.lower(), col_name].values[0]
            return price
        except IndexError:
            return None # Existing implementation

    print("Welcome to the ordering prescriptions tab!")

    while True:
        print("1. Initiate Prescription Transfer (Incoming)")
        print("2. Submit New Prescription")
        print("3. Get Drug Price")
        choice = input("Select an option (1/2/3): ")
    if choice == '1':
        print("\nInitiate Prescription Transfer (Incoming)")
        sending_pharmacy = input("Enter the name of the sending pharmacy: ")

        # Generate a random prescription number for the incoming transfer
        prescription_number = generate_prescription_number()

        print(f"Generated Prescription Number: {prescription_number}")

        fax_needed = True  # Fax is always needed for prescription transfer
        telephone_number = input("Enter the telephone number of the sending pharmacy: ")

        # Generate random prescription data for transfer
        medication, dosage, instructions, refills = generate_random_prescription_data()
        new_prescription(medication, dosage, instructions, refills, fax_needed, telephone_number)
        print(f"Prescription {prescription_number} initiated for transfer from {sending_pharmacy}. Telephone number: {telephone_number}")

    elif choice == '2':
        medication = input("Enter the medication name: ")
        dosage = input("Enter the dosage: ")
        instructions = input("Enter the instructions: ")
        refills = input("Enter the number of refills: ")

        fax_needed = input("Fax of prescription from doctor's office needed? (y/n): ").lower() == 'y'
        telephone_number = None
        if fax_needed:
            telephone_number = input("Enter the telephone number of the doctor's office: ")

        new_prescription(medication, dosage, instructions, refills, fax_needed, telephone_number)
        print("Prescription submitted successfully.")

    elif choice == '3':
        medication = input("Enter the medication name: ").lower()
        category = input("Select category (Public/Private Insurance): ").title()
        medication_type = input("Select medication type (Brand/Generic): ").title()

        manufacturer_rebate = input("Do you have a manufacturer rebate? (y/n): ")
        if manufacturer_rebate.lower() == 'y':
            has_rebate = True
        else:
            has_rebate = False

        price = get_drug_price(medication, category, medication_type)

        if has_rebate and price is not None:
            manufacturer_rebate = df.loc[df['Medication'].str.lower() == medication, f'{medication_type}_Manufacturer_Rebate'].values[0]
            price -= manufacturer_rebate

        if price is not None:
            print(f"The price of {medication_type} {medication} under {category} Insurance is ${price:.2f}")
        else:
            print("Invalid input or medication not found.")

    else:
     print("Invalid choice. Please select 1, 2, or 3.")
    another_action = input("Do you want to perform another action? (y/n): ")
    if another_action.lower() != "y":
            print("\nPrescription Database:")
            for prescription_number, prescription in prescriptions.items():
                print(f"Prescription Number: {prescription_number}")
                print(f"Medication: {prescription['medication']}")
                print(f"Dosage: {prescription['dosage']}")
                print(f"Instructions: {prescription['instructions']}")
                print(f"Refills: {prescription['refills']}")
            if 'sending_pharmacy' in prescription:
                        print(f"Sending Pharmacy: {prescription['sending_pharmacy']}")
            if 'fax_needed' in prescription:
                        print(f"Fax Needed: {'Yes' if prescription['fax_needed'] else 'No'}")
            if prescription.get('fax_needed') and 'telephone_number' in prescription:
                        print(f"Telephone Number: {prescription['telephone_number']}")
                        print("-" * 20)
      break
def p_management():
    global prescriptions, stock, delivery_status
    while True:
        print("\nPlease select an option: ")
        print("1. Refill Medication")
        print("2. Check Medication Availability")
        print("3. Check Order Status")
        print("4. Exit")

        option = input("Select the number: ")

        if option == '1':
            refill_prescription()
        elif option == '2':
            check_availability()
        elif option == '3':
            order_status()
        elif option == '4':
            break
        else:
            print("\nInvalid option. Please choose a valid option.")

def refill_prescription():
    global prescriptions, stock, delivery_status
    orders = []
    while True:
        prescription_number = input("Please enter your prescription number: ")
        while prescription_number not in [str(key) for key in prescriptions.keys()]:
            prescription_number = input("Invalid prescription number. Please try again or enter 'x' to exit WellBot: ")
            if prescription_number.lower() == 'x':
                print("Thank you for using WellBot!")
                return
        name = input("Please enter your full name: ")
        email = input("Please enter your email address: ")
        address = input("Please enter your delivery address: ")
        medicine = prescriptions[int(prescription_number)]
        order = {
            "prescription_number": prescription_number,
            "customer": name,
            "email": email,
            "address": address,
            "medicine": medicine
        }
        orders.append(order)
        print(f"\nOrder Summary:\nPrescription Number: {prescription_number}\nCustomer: {name}\nEmail: {email}\nDelivery Address: {address}\nMedicine: {medicine}")
        print("\nOrder placed! We will send you an email with the delivery information.")
        choice = input("\nWould you like to place another order? (y/n): ")
        if choice.lower() != 'y':
            break

def check_availability():
    global prescriptions, stock, delivery_status
    while True:
        medicine_name = input("Please enter the name of the medicine you want to check: ").capitalize()
        while medicine_name not in list(stock.keys()):
            medicine_name = input(f"Sorry, we don't have {medicine_name} in our inventory. Please try again or enter 'x' to exit WellBot: ").capitalize()
            if medicine_name.lower() == 'x':
                print("Thank you for using WellBot!")
                return
        available_stock = stock[medicine_name]
        if available_stock > 0:
            print(f"{medicine_name} is available, we have {available_stock} units in stock.")
        else:
            print(f"Sorry, {medicine_name} is currently out of stock.")
        choice = input("\nWould you like to check another medicine? (y/n): ")
        if choice.lower() != 'y':
            break

def order_status():
    global prescriptions, stock, delivery_status
    while True:
        prescription_number = input("Please enter your prescription number: ")
        while prescription_number not in [str(key) for key in delivery_status.keys()]:
            prescription_number = input("Invalid prescription number. Please try again or enter 'x' to exit WellBot: ")
            if prescription_number.lower() == 'x':
                print("Thank you for using WellBot!")
                return
        status = delivery_status[int(prescription_number)]
        print(f"\nThe order status for prescription number {prescription_number} is: {status}")
        if status in ['Canceled', 'On Hold', 'Rescheduled']:
            print('For further assistance, please contact our call center: 514 123 4567')
        choice = input("\nWould you like to check another order? (y/n): ")
        if choice.lower() != 'y':
            break

def fetch_medication_info(medication_name):
    api_url = f"https://api.fda.gov/drug/label.json?search=openfda.brand_name:{medication_name}&limit=1"
    response = requests.get(api_url)

    if response.status_code == 200:
        data = response.json()
        if "results" in data and data["results"]:
            medication_info = data["results"][0]
            return medication_info
    return None



def medication_information():
    medication_name = input("Enter the medication name: ")
    medication_info = fetch_medication_info(medication_name)
    if medication_info:
           print(f"Medication Name: {medication_info['openfda']['brand_name'][0]}")
           print(f"Manufacturer: {medication_info['openfda']['manufacturer_name'][0]}")

           while True:
               while True:
                   # Prompt the user for specific information
                   print("\nSelect the type of information you'd like to know:")
                   print("1. Dosage Information")
                   print("2. Allergy Information")
                   print("3. General Information/Interactions")
                   print("4. Go back to Medication Selection")
                   print("5. Return to Welcome Section")
                   print("6. Provide Feedback/Improvement")
                   print("7. Exit")

                   info_choice = input("Enter your choice: ")

                   if info_choice == "1":
                       if "dosage_and_administration" in medication_info:
                           print("Dosage and Administration:")
                           for dosage in medication_info["dosage_and_administration"]:
                               print(f"  - {dosage}")
                       else:
                           print("Dosage information not available.")

                       more_info = input("Would you like more info? (yes/no): ")
                       if more_info.lower() == "yes":
                           break
                       else:
                           return True

                   elif info_choice == "2":
                       if "warnings" in medication_info:
                           print("Allergy Information:")
                           for warning in medication_info["warnings"]:
                               print(f"  - {warning}")
                       else:
                           print("Allergy information not available.")

                       more_info = input("Would you like more info? (yes/no): ")
                       if more_info.lower() == "yes":
                           break
                       else:
                           return True

                   elif info_choice == "3":
                       # Display general information or interactions
                       # Note: You need to determine what specific information you want to display here.
                       print("General Information/Interactions:")
                       print("This section is currently not implemented.")

                       more_info = input("Would you like more info? (yes/no): ")
                       if more_info.lower() == "yes":
                           break
                       else:
                           return True

                   elif info_choice == "4":
                       return False  # Exit the medication information loop and return to main menu

                   elif info_choice == "5":
                       print("Returning to Welcome Section.")
                       return False

                   elif info_choice == "6":
                       feedback = input("Enter your feedback/improvement suggestion: ")
                       # You can implement a feedback submission mechanism here
                       print("Thank you for your feedback!")

                   elif info_choice == "7":
                       print("Thank you for using the pharmacy chatbot. Goodbye!")
                       exit()

                   else:
                       print("Invalid choice.")

           return True

    else:
           print("Medication not found.")
           return False

# Feedback
def feedback():
    while True:
        print("\nFeedback/Improvement Options:")
        print("1. Need further assistance (email/call pharmacy support)")
        print("2. Rate our service (1-10)")
        print("3. How can we improve our service")
        print("4. Go back to Welcome Menu")
        print("5. Exit")

        feedback_choice = input("Enter your choice: ")

        if feedback_choice == "1":
            print("You selected: Need further assistance.")
            print("For further assistance call us toll-free at 1-866-640-3800")
        elif feedback_choice == "2":
            rating = input("How would you rate our service (1-10)? ")
            store_rating(rating)
            print(f"You rated our service: {rating}")
        elif feedback_choice == "3":
            improvement = input("How can we improve our service? ")
            store_improvement(improvement)
            print("Thank you for your input!")
        elif feedback_choice == "4":
            return False
        elif feedback_choice == "5":
            print("Thank you for using the pharmacy chatbot. Goodbye!")
            exit()
        else:
            print("Invalid choice.")

    return True

def store_improvement(suggestion):
    try:
        with open("improvements.json", "r") as f:
            improvements = json.load(f)
    except (FileNotFoundError, json.JSONDecodeError):
        improvements = []

    # Add the new suggestion
    improvements.append(suggestion)

    # Write the updated improvements to the JSON file
    with open("improvements.json", "w") as f:
        json.dump(improvements, f, indent=4)

def store_rating(rating):
    try:
        with open("ratings.json", "r") as f:
            ratings = json.load(f)
    except (FileNotFoundError, json.JSONDecodeError):
        ratings = []

    # Add the new rating
    ratings.append(rating)

    # Write the updated ratings to the JSON file
    with open("ratings.json", "w") as f:
        json.dump(ratings, f, indent=4)

def feedback():
    while True:
        print("\nFeedback/Improvement Options:")
        print("1. Need further assistance (email/call pharmacy support)")
        print("2. Rate our service (1-10)")
        print("3. How can we improve our service")
        print("4. Go back to Welcome Menu")
        print("5. Exit")

        feedback_choice = input("Enter your choice: ")

        if feedback_choice == "1":
            print("You selected: Need further assistance.")
            print("For further assistance call us toll-free at 1-866-640-3800")
        elif feedback_choice == "2":
            rating = input("How would you rate our service (1-10)? ")
            store_rating(rating)
            print(f"You rated our service: {rating}")
        elif feedback_choice == "3":
            improvement = input("How can we improve our service? ")
            store_improvement(improvement)
            print("Thank you for your input!")
        elif feedback_choice == "4":
            return False
        elif feedback_choice == "5":
            print("Thank you for using the pharmacy chatbot. Goodbye!")
            exit()
        else:
            print("Invalid choice.")
